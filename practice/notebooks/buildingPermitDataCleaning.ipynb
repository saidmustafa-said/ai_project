# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# set seed for reproducibility
np.random.seed(0)

# %%
df = pd.read_csv("../data/raw/Building_Permits.csv")

# %%
df.head()

# %%
df.isnull().sum(axis=0)
total_value = df.shape[1] * df.shape[0]
total_value

# %%
total_null = df.isnull().sum(axis=0).sum()
total_null

# %%
percent  = (total_null / total_value) * 100
percent

# %%
df['Zipcode']

street_number_suffix_missing = df['Street Number Suffix'].isnull().sum()
zipcode_missing = df['Zipcode'].isnull().sum()

print("Number of missing values in 'Street Number Suffix':",street_number_suffix_missing)
print("Number of missing values in 'Zipcode':", zipcode_missing)

# %%
new_df = df

# %%
new_df = new_df.dropna()

new_df.shape

# %%
column_drop = df.dropna(axis=1)
column_drop
